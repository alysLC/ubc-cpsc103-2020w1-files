# %% [markdown]
# <span style="color:red">
#     <h1>Sample Solution</h1>
#
# This is a sample solution to the practice exam. As always, this is just *one* solution. There may be many other ways to solve these problems correctly. Be sure you understand **why** this solution is correct and how it relates to your own solution.
# </span>

# %% [markdown]
# # Exam Rules
#
# We divide the rules into two parts: The part specific to CPSC 103 that you need to read, and UBC's recommended rules for students to agree to.
#
# ## The Part We Absolutely Need You to Read
#
# ### Your Work Is Your Own
#
# Your work on the exam must be **your own individual work**. You may not discuss the exam in any way with anyone outside of the course staff for CPSC 103.
#
# If you get (or give!) assistance from someone who is not CPSC 103 course staff on the CPSC 103 exam, you should expect a grade of 0 on your exam and an academic misconduct case against you.
#
# **Possible exception:** We are switching to online exams in crisis mode. If you have technical issues *with the online format*, you should ask those of the CPSC 103 course staff. In an emergency you may ask assistance from someone else **ONLY** on such technical issues. You **MUST** acknowledge that person by name with their contribution in the cell below. **DO NOT** take (or give) any assistance on the content of the exam as part of this emergency assistance, not even help reading the questions.
#
# ### Respect Your Classmates' Lecture Time
#
# Do not access Syzygy/Jupyter during the other section's registered time (12:30-2 if you are in the 3:30-5 section; 3:30-5 if you are in the 12:30-2 section). If possible, complete and submit your exam during your lecture timeslot.
#
# ### You May Use CPSC 103 Resources on Canvas, Syzygy/Jupyter, and Piazza
#
# You have access to all our term's content on Canvas, Syzygy/Jupyter, and Piazza. That includes, for example, our design recipes.
#
# However, Piazza will be closed to new posts during the exam. To ask a question, go to the office hours and help sessions room in Collaborate Ultra at https://canvas.ubc.ca/courses/35980/external_tools/5284, "raise your hand", and wait for a course staff member to chat privately with you.
#
# ### Submission Format and Deadline
#
# You must download your Jupyter Notebook as a Python (.py) file and submit it on gradescope (https://www.gradescope.ca/courses/46) to receive credit for the exam. Full credit is available only for submissions completed by 8PM. We accept late submissions at a deduction of 2.5% point per hour (or portion of an hour) up to four hours later (midnight). (The exam is pass/fail; so, the grade deduction simply makes it harder to earn a "pass".)
#
# Instructions on submitting the exam are at the end of this file.
#
# ## The Other Part You Are Agreeing To
#
# I hereby pledge that I have read and will abide by the rules, regulations, and expectations set out in the Academic Calendar, with particular attention paid to:
# 1. The Student Declaration (http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,285,0,0)
# 2. The Academic Honesty and Standards http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,286,0,0
# 3. The Student Conduct During Examinations http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,41,90,0
# 4. The special rules for conduct as set out above, and any additional rules set out by the examiner during the exam period.
#
# I affirm that I will not give or receive any unauthorized help on this examination, that all work will be my own, and that I will abide by any special rules for conduct set out by the examiner.

# %% [raw]
# You are REQUIRED to agree to these exam rules to participate in the exam.
#
# Submitting your exam to gradescope indicates your agreement with these rules.
#
# If you received emergency technical assistance (see rules on that above), acknowledge everyone who gave it here in this format:
# + NAME OF PERSON PROVIDING ASSISTANCE, RELATIONSHIP OF THAT PERSON TO YOU, NATURE OF ASSISTANCE GIVEN

# %% [markdown]
# # IMPORTANT NOTE ON OUR ONLINE EXAMS
#
# Your online exam work will be in Jupyter to make it easy and comfortable to type out your code (and to download it as a "Python (.py)" file for submission), but **DO NOT EXPECT EVERYTHING TO RUN**.
#
# First, we will supply various helper functions as simple stubs and you will supply csv "files" as markdown inside this file; so, your code will not run correctly. Second, your focus and emphasis should be on **following our design process**, just as in on-paper exams, and not on perfection.
#
# Also, as always, **THROUGHOUT the exam:** If we ask you to design a solution, we mean to design it using the appropriate design recipes (i.e., HtDF, HtDD, or both) taught in CPSC 103.

# %%
from cs103 import *
from enum import Enum
from typing import List, NamedTuple, Optional
import csv

# %% [markdown]
# # Practice Exam

# %% [markdown]
# The following problems are about *Piazza posts with endorsements* with file structure and data definitions adapted from the exam preparation material. Changes are noted in **_bold italics_** below.
#
# Information about Piazza questions is available in a CSV file in a format like the following:
#
# | QID | Question           | I Ans               | S Ans                   | Endorse |
# |-----|--------------------|---------------------|-------------------------|---------|
# |   2 | What is 6 x 9?     | It’s 54.            | 42                      | SSISI   |
# |  73 | How is everything? | Everything is fine. | No it’s not.            |         |
# |   5 | Huh?               |                     | Can you please clarify? | SS      |
#
# **_Note: Compared to the prep material, the `I Ans` column has been moved left and the format/contents of `I Ans` and `S Ans` have been changed._**
#
# Each row has:
# + The question ID (a positive number, where no two questions have the same number)
# + The text of the question
# + The text of the instructor answer (if any, blank otherwise)
# + The text of the student answer (if any, blank otherwise)
# + The endorsements given to the student answer. This is a series of letters either `S` or `I`, each representing an endorsement by a student (S) or instructor (I) in the order they were given. If there is no student answer, there cannot be any endorsements.
# So, the student answer to question 2 above was endorsed by two students, then an instructor, then another student, and finally another instructor.
#
# We are interested in the question ID, whether the question has a student answer, **_the number of endorsements of the student answer_**, and whether the question has an instructor answer. We represent them with these data definitions:

# %%
Question = NamedTuple('Question', [('number', int),       # in range [1, ...]
                                   ('has_s_answer', bool),
                                   ('num_endorse', int),  # in range[0, ...] # CHANGED HERE
                                   ('has_i_answer', bool)])
# interp. a Piazza question with its number (no two questions in a course 
# have the same number), whether it has a student answer (has_s_answer), 
# the number of endorsements that answer has received (num_endorse; 0 if 
# there is no student answer), and whether it has an instructor answer 
# (has_i_answer).
Q1 = Question(1, True, 2, True)         # CHANGED HERE
Q2 = Question(19, False, 0, False)      # CHANGED HERE

@typecheck   # template based on compound (4 fields)
def fn_for_question(q: Question) -> ...:
    return ...(q.number, q.has_s_answer, q.num_endorse, q.has_i_answer)  # CHANGED HERE

# List[Question]
# interp. a list of Piazza questions
LOQ0 = []
LOQ1 = [Q1, Q2]

# template based on arbitrary-sized and reference rule (Question)
@typecheck
def fn_for_loq(loq: List[Question]) -> ...:
    # description of accumulator
    acc = ...   # type: ...
    
    for q in loq:
        acc = ...(acc, fn_for_question(q))
        
    return ...(acc)

# %% [markdown]
# ## Problem 1 (worth TODO marks)
#
# We changed the name of the attribute `is_endorsed` in the `Question` data type definition above to `num_endorse` and correctly updated its description in the `Question` interpretation. Neatly edit the code above to change everything else in the `Question` data definition that should also change as a result.

# %% [markdown]
# <span style="color:red">Look in the data definitions above for
# comments like <code>CHANGED HERE</code>.</span>
#
# <span style="color:red">I needed to change the type of <code>num_endorse</code>. It's an integer, since one cannot have a half-endorsement. (Well, maybe Bernie Sanders of Hillary Clinton in 2016, but you'd have to be an election geek to even get that.) One can't have fewer than 0 endorsements, either. So, I added a range comment as well. Down below, I just checked for consistency in each part. The examples used Booleans; I changed those to (corresponding) integers. The template used the old name; I fixed that.
# </span>

# %% [markdown]
# ## Problem 2 (worth TODO marks)
#
# Now, **neatly edit the `read` template below and add tests** to complete a function design to read csv files in this format into a `List[Question]`. Complete **all design steps**, including **fully** designing any required helper functions!
#
# Be careful as the file's format and column ordering does not always nicely match our data definitions!

# %% [markdown]
# Assume the table above is available in a file named `test_given.csv`. If you need additional test files:
# 1. double-click this markdown cell,
# 2. add them as they would be in a csv file with triple-backquotes around them, and
# 3. indicate their file names.
#
# For example, here is a blank test file you can also use:
#
# ```
# File test_empty.csv contains:
#
# QID,Question,I Ans,S Ans,Endorse
# ```
#
# Put any additional test files below:
#
# <span style="color:red">The two test files given mostly do a good job of testing <code>read</code>, but there's one notable thing missing: the student answer was never empty. I'll make one example to test that. (I almost gave it endorsements as well, but the description of the file above makes clear that's not possible if there's no student answer.) I'll copy-and-paste the blank test file above and edit it to have an example with a blank student answer:</span>
#
# ```
# File test_blank_sa.csv contains:
#
# QID,Question,I Ans,S Ans,Endorse
# 1,Is 76 larger than 75?,when the wind is westerly,,
# ```
# <span style="color:red">Now I'm ready to edit the <code>read</code> template, and thinking about test cases helps in figuring out what I want to do there. I always do the "bookkeeping" parts first: renaming <code>Consumed</code> to the real data definition name and all the things that go with that (e.g., renaming <code>loc</code>). Once I've done that, I'll switch back to following the HtDF steps: signature, purpose, stub, examples, function body.</span>
#
# <span style="color:red">By the way, the examples aren't going to run because I don't actually have the files I described above. That's <strong>OK</strong>. We expect that on the exam. Remember: focus on good design, not lack of errors and perfection in the code.</span>

# %%
@typecheck
def read(filename: str) -> List[Question]:
    """    
    reads information from the specified file and returns the corresponding list of questions
    """
    # return []  #stub
    # Template from HtDAP

    # loq contains the result so far
    loq = [] # type: List[Question]

    with open(filename) as csvfile:

        reader = csv.reader(csvfile)
        next(reader) # skip header line

        for row in reader:
            # recall that row is a List[str]
            
            # from the data definitions above, I know Question has four attributes:
            # number (an int, guaranteed), has_s_answer (a bool that reflects whether 
            # there's ANY student answer at all or a blank), num_endorse (an int based
            # on the number of endorsements in the S/I string in the last column), and
            # has_i_answer (a bool like the one for has_s_answer).
            
            # Working through the examples below helped me figure out how to set the values
            # of these attributes:
            
            # number is straightforward to get using parse_int (which we know will
            # return an int and not None since we know from the description of the files
            # above that the number column only contains actual integers).
            
            # the two answer bools both require reasoning about whether the column is
            # empty. I created a helper function for that and used that same helper for
            # both columns
            
            # the length of the S/I string in the last column tells us the number of
            # endorsements. You could create a helper to manage that, which in turn would
            # use the len function. I just used len directly, which is also OK. (Easier,
            # if perhaps less flexible in the face of future design changes.)
            
            # The last tricky thing to figure out is which column is which. Here are
            # the headers: QID,Question,I Ans,S Ans,Endorse. So, number is in row[0],
            # we don't care about row[1], the instructor answer is in row[2], the student
            # answer in row[3], and the endorsements in row[4].
            
            q = Question(parse_int(row[0]),
                         has_answer(row[3]),
                         len(row[4]),
                         has_answer(row[2]))
            loq.append(q)

    return loq

@typecheck
def has_answer(anwser_text: str) -> bool:
    """
    return True if answer_text is non-empty, False otherwise
    """
    #return False  #stub
    #return ...(answer_text)  #stub
    
    # != means not equal to
    # an if/else and using len rather than comparing against ""
    # would also work fine.
    return answer_text != ""


start_testing()
expect(read('test_empty.csv'), [])
expect(read('test_given.csv'), [Question(2, True, 5, True),
                                Question(73, True, 0, True),
                                Question(5, True, 2, False)])
expect(read('test_blank_sa.csv'), [Question(1, False, 0, True)])
summary()

start_testing()
expect(has_answer(""), False)
expect(has_answer("anything"), True)
summary()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-444bcdcb9448> in <module>
#      68
#      69 start_testing()
# ---> 70 expect(read('test_empty.csv'), [])
#      71 expect(read('test_given.csv'), [Question(2, True, 5, True),
#      72                                 Question(73, True, 0, True),
#
# /opt/conda/lib/python3.7/site-packages/cs103/typecheck/typecheck.py in wrapper(*args)
#     133                 raise TypeError("The function \x1b%s\x1b is missing a type for the parameter %s." % (fn.__name__, name))
#     134
# --> 135         retval = fn(*args)
#     136         if 'return' in types:
#     137             subtype("the returned value", retval, types['return'], fn, True)
#
# <ipython-input-3-444bcdcb9448> in read(filename)
#      10     loq = [] # type: List[Question]
#      11
# ---> 12     with open(filename) as csvfile:
#      13
#      14         reader = csv.reader(csvfile)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_empty.csv'

# %% [markdown]
# ## Problem 3 (worth TODO marks)
#
# Now, **complete the design of the `get_pri_q_urls` function below** (tests, body, and any helper functions not already available for your use). You may not change the provided signature, purpose, stub, or how the function is templated. (I.e., you must use the `List[Question]` template.)
#
# You should assume the `get_priority` and `str` functions that are just stubs below are complete, correct, and available for your use. **DO NOT** complete the `get_priority` and `str` functions as part of this problem.

# %% [markdown]
# <span style="color:red">There isn't much description of <code>get_pri_q_urls</code> above; so, it's critical to go down and read the purpose below before starting. I did that. Once I had read it (which also led me to read <code>get_priority</code> so I would understand priorities a bit better), I dove in on the design of the function, being sure after I finished the tests to follow the <code>List[Question]</code> template by copy-and-pasting it from the data definitions above.</span>

# %%
## ASSUME that:
## + CS103_PIAZZA contains the start of question web addresses (URLs) on Piazza
## + get_priority and str are CORRECT AND COMPLETE and available for your use.
##
## DO NOT complete these functions as part of the work for this problem.

CS103_PIAZZA = "..."  # DO NOT CORRECT MY VALUE

@typecheck
def get_priority(q: Question) -> int:
    """
    return the priority of q (how urgently it needs attention, where higher is more urgent).
    Note: no student and no instructor answer results in the highest priority: 4;
    no instructor answer but a student answer with no endorsements gives priority: 3;
    no instructor answer but a student answer with endorsements gives priority: 2;
    otherwise there is an instructor answer, and the priority is 1.
    """
    return 0  #stub
    ## DO NOT COMPLETE ME

@typecheck
def str(i: int) -> str:
    """
    return i as a string. E.g., str(7) is "7".
    """
    return ""   #stub
    ## DO NOT COMPLETE ME

# %%
## DONE: complete the design of get_pri_q_urls, without changing the 
## existing signature, purpose, or stub. Use the List[Question] template.
@typecheck
def get_pri_q_urls(loq: List[Question], pri: int) -> List[str]:
    """
    return the URLs of all questions in loq with priority of pri or more.
    
    Note:
    + pri is in the range [1, 4] (the only legal priority values)
    + the URL of a question is the string stored in CS103_PIAZZA
      followed by the question number. For example for question
      number 12, the URL is: CS103_PIAZZA + str(12)
    """
    return []  #stub
    # template from List[Question] w/addl parameter pri
    
    # As I pulled my examples together, I thought about what I would
    # do to solve the problem (especially with my longer example!).
    
    # I needed to ask for each one "is its priority appropriate".
    # Then, if it was, I needed to get its URL and track that in a list.
    # So, the list of URLs is my accumulator, and I need helper functions
    # to help me with priorities (already have one!) and URL transformation.
    
    # urls is the list of URLs of priority questions seen so far
    urls = []   # type: List[str]
    
    for q in loq:
        if get_priority(q) >= pri:
            urls.append(form_q_url(q))
        
    return urls

@typecheck
def form_q_url(q: Question) -> str:
    """
    returns the URL for q
    
    the URL of a question is the string stored in CS103_PIAZZA
    followed by the question number. For example for question
    number 12, the URL is: CS103_PIAZZA + str(12)
    """
    #return ""  #stub
    # template from Question
    return CS103_PIAZZA + str(q.number)

start_testing()

# I'd like to have questions at each priority level for testing.
# It'll be convenient for me to make them here so I can easily find and refer to them.
# I started by copy-and-pasting an example from the data definition and editing it.

# It's not clear you need EVERY priority for testing, but you certainly want more than
# one question, to test that varying the priority passed in with the same list correctly
# adjusts the result, and to test key cases (probably: something at the priority cutoff,
# something above the priority cutoff, and something JUST below the priority cutoff).

QPRI1_A = Question(10, True, 1, True)    # has an i answ
QPRI1_B = Question(26, False, 0, True)   # still has an i answ so still priority 1
QPRI2 = Question(3, True, 1, False)      # no i answ, but an endorsed s answ
QPRI3 = Question(14, True, 0, False)     # no i answ, s answ present but no endorsements
QPRI4 = Question(5, False, 0, False)     # no answer at all

TEST_QPRI_LIST = [QPRI2, QPRI1_A, QPRI3, QPRI4, QPRI1_B]  # shuffled the order a bit to emphasize order doesn't matter

# Empty list tests:
expect(get_pri_q_urls([], 1), [])
expect(get_pri_q_urls([], 4), [])

# Real list tests:

# everything is priority 1 or more
expect(get_pri_q_urls(TEST_QPRI_LIST, 1), [CS103_PIAZZA + "3",
                                           CS103_PIAZZA + "10",
                                           CS103_PIAZZA + "14",
                                           CS103_PIAZZA + "5",
                                           CS103_PIAZZA + "26"])  

# I'll "cull" some in a couple of tests:
expect(get_pri_q_urls(TEST_QPRI_LIST, 3), [CS103_PIAZZA + "14",
                                           CS103_PIAZZA + "5"])
expect(get_pri_q_urls(TEST_QPRI_LIST, 4), [CS103_PIAZZA + "5"])

summary()

start_testing()
# There's little interesting variation here. Just two examples is enough!
# I ensured the two examples had different digit lengths in their numbers..
# but that was probably overkill!
expect(form_q_url(QPRI1_A), CS103_PIAZZA + "10")
expect(form_q_url(QPRI2), CS103_PIAZZA + "3")
summary()

# %% [markdown]
# ## Problem 4 (worth TODO marks)
#
# Now, **complete JUST THE BODY of the alternate implementation of the `get_pri_q_urls` function below**. It has the same signature, purpose, and stub as above. You may not change how the function is templated. In particular, you must **follow the composition plan provided**. Do **not** supply tests, since you already supplied them above.
#
# You should assume the `prepend_strings` function that is just a stub below is complete, correct, and available for your use. **DO NOT** complete the `prepend_strings` function as part of this problem.
#
# Otherwise, **where you need a helper function, design only its signature, purpose, and stub in the same cell as `prepend_strings` and then assume like `prepend_strings` that it is complete and correct.**

# %% [markdown]
# <span style="color:red">I'm implementing the same function again, but this time by composition. Happily, I am given a composition plan (although I still need to read and understand it) and I don't have to actually design helper functions I use beyond the signature/purpose/stub. (As an aside, that's called "stubbing the functions out".)</span>
#
# <span style="color:red">I took each plan step line-by-line and converted it into a call to a helper function (or used an existing helper function where I had one). I chose clear names that suggested what I wanted to do, passed in whichever data that step would need to operate, stored the results in variables with clear names (nouns, rather than verbs like the functions), and stitched together the solution that way.</span>
#
# <span style="color:red">Once I had that, I copied-and-pasted those lines into the cell above and edited them to create stubs for the new functions. There were lots of clues as to what the signature and purpose should look like based on the work I had done and what was already in <code>get_pri_q_urls</code>'s signature and purpose. One thing I was very careful about was to avoid having one helper function know anything about other helper functions' work. Just like <code>prepend_strings</code> doesn't know anything about Questions or even URLs, my other helpers don't need to (and <strong>should not</strong>) know about each other. (As a concrete example, it would be <strong>poor design</strong> to have the <code>get_q_numbers</code> helper function say in its purpose or via the name of its parameter that it takes "high priority questions". It doesn't know or care whether the questions it operates on are high priority; it only knows how to extract the numbers from questions. Read the purpose of <code>nums_to_strs</code> below for an even more dramatic example of a helper function not knowing much! 😁)</span>

# %%
## ASSUME that:
## + CS103_PIAZZA contains the start of question web addresses (URLs) on Piazza
## + prepend_strings--and any functions whose signatures, purposes, and stubs
##   you add here--are CORRECT AND COMPLETE and available for your use

CS103_PIAZZA = "..."  # DO NOT CORRECT MY VALUE

## DONE: add here any signatures, purposes, and stubs for any helper
##       functions required by your get_pri_q_urls design below.

@typecheck
def prepend_strings(los: List[str], s: str) -> List[str]:
    """
    returns the result of adding s to the start of each string in los
    (i.e., "prepending" s to each string)
    """
    return los  #stub
    ## DO NOT COMPLETE ME
    
@typecheck
def filter_to_high_pri(loq: List[Question], min_pri: int) -> List[Question]:
    """
    returns all questions in loq with a priority of min_pri or higher
    
    (min_pri should be a number in the range [1, 4].)
    """
    return loq  #stub

@typecheck
def get_q_numbers(loq: List[Question]) -> List[int]:
    """
    returns a list of the questions numbers of the questions in loq
    """
    return []  #stub

@typecheck
def nums_to_strs(loi: List[int]) -> List[str]:
    """
    return loi as a list of strings
    """
    return []  #stub

# %%
## DONE: complete the design of get_pri_q_urls, without changing
## the existing signature, purpose, or stub. Use the provided 
## composition plan. 
##
## DO NOT FORGET to design signatures, purposes, and stubs for any
## new helpers in the cell above.
@typecheck
def get_pri_q_urls(loq: List[Question], pri: int) -> List[str]:
    """
    return the URLs of all questions in loq with priority of pri or more.
    
    Note:
    + pri is in the range [1, 4] (the only legal priority values)
    + the URL of a question is the string stored in CS103_PIAZZA
      followed by the question number. For example for question
      number 12, the URL is: CS103_PIAZZA + str(12)
    """
    return []  #stub
    # template from composition
    # Plan:
    # 1) filter to questions with a high enough priority, 
    # 2) get the questions numbers, 
    # 3) convert them to strings, and
    # 4) convert those strings to URLs.
    # NOTE: FOR FULL CREDIT, step 4 must use prepend_strings.
    
    high_pri_qs = filter_to_high_pri(loq, pri)
    qnums = get_q_numbers(high_pri_qs)
    qnums_as_strs = nums_to_strs(qnums)
    return prepend_strings(qnums_as_strs, CS103_PIAZZA)

    
start_testing()
## DO NOT ADD TESTS. You should assume they are already complete.
summary()

# %% [markdown]
# ## Problem 5 (worth TODO marks)
#
# **Complete the design of the graphing function below.** Ensure that the produced graph has a good title and axis labels and remember to complete all remaining steps of the HtDF recipe including tests.
#
# **DO NOT insert images into this file as we will not see them in grading.** (Sorry! You have to describe graphs in English rather than sketching them.)
#
# You should assume the `get_pri_percents` and `get_percent` functions that are just stubs below are complete, correct, and available for your use. **DO NOT** complete the `get_pri_percents` and `get_percent` functions as part of this problem.

# %% [markdown]
# <span style="color:red">Module 8!</span>
#
# <span style="color:red">OK. You can do this. When you get to templating and implementing the body, you can even go to the line chart worked example if you want and copy-and-paste its body to help get you started!</span>
#
# <span style="color:red">My first step was to read the signature and especially purpose of <code>graph_q_pris</code>, since there isn't much above. Once I understood that, I wrote my tests, which is both what comes next after the sig/purp/stub in HtDF, a good next step to take to understand the function, and the most likely step for me to forget! As I got set for that, I realized I could reuse the example I made above with questions at various priority levels. So, I copy-and-pasted it down for reference.</span>
#
# <span style="color:red">Sadly, I'm not allowed to insert images into the notebook and submit on gradescope. So, I did straight-up English descriptions. (I <strong>almost</strong> said my empty-list test's graph was empty, but I realized there are <strong>always</strong> four points. It's just that they'd all be at 0% in this case.) Two tests felt like plenty, as there's not much more exciting going on than my two tests illustrate (though it was very handy that I had a test already to show variation in each of the four points).</span>
#
# <span style="color:red">Note that <code>get_percent</code> seems very handy to implement <code>get_pri_percents</code>, but I didn't need it at all for my graphing function. That's fine! Nothing says I MUST use all helpers available!</span>
#
# <span style="color:red">AFTER THE FACT NOTE: Here and in some other places, I forgot to comment out our stubs. That's certainly a mistake you'd want to fix in a tutorial submission. For the exam, it doesn't matter. We're not focused on exact correctness but on good design overall. Forgetting to comment out the stub just doesn't matter from a design perspective.</span>

# %%
## ASSUME that: get_pri_percents and get_percent are 
## CORRECT AND COMPLETE and available for your use.
##
## DO NOT complete these functions as part of the work for this problem.

@typecheck
def get_pri_percents(pris: List[int], loq: List[Question]) -> List[float]:
    """
    returns the percentages of questions in loq that are of each 
    priority in pris or higher; percentages are 0 if loq is empty
    """
    return []   #stub
    ## DO NOT COMPLETE ME

@typecheck
def get_percent(value: int, total: int) -> float:
    """
    returns value as a percent of total, returning 0 if total is 0
    """
    return 0.0   #stub
    ## DO NOT COMPLETE ME

# %%
## TODO: complete the design of graph_q_pris, without changing the
## existing signature, purpose, stub, or template comment.


@typecheck
def graph_q_pris(loq: List[Question]) -> None:
    """
    Draws a line chart showing the percentage of questions at or above each 
    priority level 1, 2, 3, and 4. The percentage is defined to be 0 if there are 
    no questions. (The line will always have exactly four points with x values 1, 
    2, 3, and 4. As it happens, point 1 will always be at 100, unless there are no 
    questions, since all questions have priority 1 or more.)
    """
    return None  #stub

    # template from viz
    pyplot.xlabel("Priority")
    pyplot.ylabel("Percent of questions")
    pyplot.title("Questions at or above each priority level")
    
    x_vals = [1, 2, 3, 4]  # these are always and exactly the x values
    y_vals = get_pri_percents(x_vals, loq)
    pyplot.plot(x_vals, y_vals)
    
    # You do NOT need to include these. I do out of habit.
    # Either way is OK!
    pyplot.show()
    return None

    
start_testing()

QPRI1_A = Question(10, True, 1, True)    # has an i answ
QPRI1_B = Question(26, False, 0, True)   # still has an i answ so still priority 1
QPRI2 = Question(3, True, 1, False)      # no i answ, but an endorsed s answ
QPRI3 = Question(14, True, 0, False)     # no i answ, s answ present but no endorsements
QPRI4 = Question(5, False, 0, False)     # no answer at all

TEST_QPRI_LIST = [QPRI2, QPRI1_A, QPRI3, QPRI4, QPRI1_B]  # shuffled the order a bit to emphasize order doesn't matter


# DO NOT insert images into this file as we will not see them in grading.
# You will have to describe the expected graph in English instead :(

# Should draw a graph with x axis "Priority", y axis "Percent of questions",
# title "Questions at or above each priority level", and four points at x
# values 1, 2, 3, and 4 and all at y value 0.
expect(graph_q_pris([]), None)

# Should draw a graph like the one above except the y values of the points
# at x=1, 2, 3, 4 should be (in order): 100, 60, 40, 20. (So, a falling line
# with a steep drop between x=1 and x=2 and steady drop otherwise.)
expect(graph_q_pris(TEST_QPRI_LIST), None)

summary()

# %% [markdown]
# ## Now Submit
#
# First, go back and be sure you've completed each step we've asked for in each design **AND** acknowledged the exam rules at the top.
#
# (Common steps to forget include tests, where we require them, and however much we ask for you to complete of helper functions you call.)
#
# To submit the exam:
#
# 1. Click the `File` menu, go to the `Download as` submenu, and select `Python (.py)`. This will download your exam work to your computer as a Python file, i.e., one ending in `.py`.
# 2. Log in to gradescope with the same account you used to access Midterm 1. (If you don't recall your account, check out https://piazza.com/class/k4acympiwak4u?cid=359.)
# 3. Click the Practice Exam "assignment". **_For the actual midterm, the assignment will be named "Midterm 2"._**
# 4. You should immediately see a window in which to upload your exam submission.
# 5. Either click the box and find your `.py` file or drag-and-drop your `.py` file into the box.
# 6. Click the "Upload" button.
# 7. Review your submission. Click the "Code" button in the viewing window. You should be able to see your submission. Your markdown cells' contents will appear as comments but should still be readable. Be sure it is the right submission!!
#
# If you need to resubmit, follow the same steps except that after clicking the "assignment", you will click the "Resubmit" button in the lower-right before seeing the window in which to upload your submission.
