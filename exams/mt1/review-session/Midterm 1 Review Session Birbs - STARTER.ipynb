# %% [markdown]
# ![ubc%20birb.jpg](attachment:ubc%20birb.jpg)

# %% [markdown]
# # Bird Watching
#
# ## You have recently become an avid bird-watcher and enjoy going to Pacific Spirit Park to see many different kinds of birds and/or posting pictures of them to reddit. To make sure that the birds you want to see will be in Pacific  Spirit Park, you'd like a way to represent your favourite birds and what their bird watching season is. Eventually you want a way to determine if you are within the bird watching season for any given bird, during a particular month you give as input.
#
# ## The chart below shows information about the bird wathcing seasons for your favourite birds. The green blocks indicate the months in which you *can* spot the bird, the grey blocks are for months you *cannot* spot the bird

# %% [markdown]
# ![bird_season.png](attachment:bird_season.png)
#
# Data From: [ebird.org](https://ebird.org/home)
#
# [Create your own region specifc data from here](https://ebird.org/GuideMe?cmd=changeLocation)

# %% [markdown]
# ## Question 1
#
# #### Design a data definition to represent different types of birds. Each bird has a name, the start month of the bird watching season, and an end month of the season.
#
# #### Assume that each bird watching season extends from a single start month to a single end month, with no gaps.
#
# For example:
#
# the Great Blue Heron has a season from March to August
# The Icelandic Gull's season is from November to January (rather than saying January, November and December. The season must have no gaps)
#
#
# Make sure to follow the HtDD recipe.
#
# You can use the chart above to know when a bird's bird-watching season is.

# %%
# Your Data Definitions go here

# %% [markdown]
# ## Question 2
#
# #### Design a function that takes a bird (b) and an integer (m) to represent a month. Use that function to determine whether  bird b is found in Pacific Spirit Park in that month m. Make sure to follow the  HtDF recipe.
#
# For example, since the Iceland Gull has a bird-watching season from November to January, you can spot it in Pacific Spirit Park in December but not in March.

# %% [markdown]
# <a href="https://imgflip.com/i/3d44gz"><img src="https://i.imgflip.com/3d44gz.jpg" title="made at imgflip.com"/></a>

# %%
## Your solution here
